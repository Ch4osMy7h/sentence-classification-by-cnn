# %% [markdown]
# ## Datasets (SST)

# %%
from pathlib import Path
from sklearn.model_selection import train_test_split 
from tqdm import trange
import numpy as np
from gensim.models.keyedvectors import KeyedVectors
import torchtext
import torch
import torch.nn as nn
import torch.nn.functional as F
import time
import copy
import nltk

# %%
TEXT = torchtext.data.Field(lower=True, include_lengths=True, batch_first=True)
LABEL = torchtext.data.Field(sequential=False)
train, val, test = torchtext.datasets.SST.splits(TEXT, LABEL, root="data/", fine_grained=True)
TEXT.build_vocab(train, vectors="glove.840B.300d")
LABEL.build_vocab(train, val, test)
train_iter, val_iter, test_iter = torchtext.data.BucketIterator.splits(
    (train, val, test), batch_size=50 , device=0)
# Out:
# 100%|█████████▉| 2195990/2196017 [05:02<00:00, 7501.04it/s]The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# The `device` argument should be set by using `torch.device` or passing a string as an argument. This behavior will be deprecated soon and currently defaults to cpu.
# 100%|█████████▉| 2195990/2196017 [05:20<00:00, 7501.04it/s]

# %% [markdown]
# ## Model

# %%
## 直接实现CNN_MULTICHANNEL
class CNN(nn.Module):
    def __init__(self, dim = 300):
        super(CNN, self).__init__()
        self.fliters = [3, 4, 5]
        self.fliters_num = [100, 100, 100]
        self.dropout_prob = 0.5
        self.classes = len(LABEL.vocab)-1
        self.embedding_dim = dim
        
        self.embedding = torch.nn.Embedding.from_pretrained(TEXT.vocab.vectors)
        self.embedding_pretrain = torch.nn.Embedding.from_pretrained(TEXT.vocab.vectors, False)
        
        self.conv_1 = torch.nn.Conv2d(2, self.fliters_num[0], (self.fliters[0], self.embedding_dim))
        self.conv_2 = torch.nn.Conv2d(2, self.fliters_num[1], (self.fliters[1], self.embedding_dim))
        self.conv_3 = torch.nn.Conv2d(2, self.fliters_num[2], (self.fliters[2], self.embedding_dim))
        self.dropout = nn.Dropout(self.dropout_prob)
        self.fc = nn.Linear(300, self.classes)
        
    def forward(self, input):
        i1 = self.embedding(input)
        i2 = self.embedding_pretrain(input)
        x = torch.stack([i1, i2], dim = 1)
        x1 = F.relu(self.conv_1(x)).squeeze(3)
        x1 = F.max_pool1d(x1, x1.shape[1]).squeeze(2)
        x2 = F.relu(self.conv_1(x)).squeeze(3)
        x2 = F.max_pool1d(x2, x2.shape[1]).squeeze(2)
        x3 = F.relu(self.conv_1(x)).squeeze(3)
        x3 = F.max_pool1d(x3, x3.shape[1]).squeeze(2)
        x = torch.cat((x1, x2, x3), 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
SETS = ['train', 'test', 'val']
dataloaders = {}
dataloaders['train'] = train_iter
dataloaders['test'] = test_iter
dataloaders['val'] = val_iter

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = CNN().to(device)
params = filter(lambda x : x.requires_grad, model.parameters())
optimzer = torch.optim.Adadelta(params, lr=1e-2)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## Train

# %%
def train_val(model, criterion, optimizer, num_epochs=100):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    for epoch in range(num_epochs):
        print('Epoc {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            running_loss = 0.0
            running_corrects = 0
            for index, data in enumerate(dataloaders[phase]):
                inputs, labels = data.text[0], data.label
                labels.sub_(1)
                inputs, labels = inputs.to(device), labels.to(device)
            
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    # Forward pass
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    # Compute loss
                    loss = criterion(outputs, labels)

                    # Compute gradients and update parameters if train
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size()[0]
                running_corrects += torch.sum(preds == labels).item()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
        
            print('{} Loss: {:.4f} Acc.: {:.2f} %'.format(
                phase.title(), epoch_loss, epoch_acc * 100))
        
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()
    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best Accuracy: {:.2f} %'.format(best_acc * 100))
    model.load_state_dict(best_model_wts)
    
    return model

# %%
model = train_val(model, criterion, optimzer)
# Out:
# Epoc 0/99
# ----------
# Train Loss: 1.6027 Acc.: 24.51 %
# Val Loss: 1.5631 Acc.: 31.06 %
#
# Epoc 1/99
# ----------
# Train Loss: 1.5617 Acc.: 29.31 %
# Val Loss: 1.5492 Acc.: 30.61 %
#
# Epoc 2/99
# ----------
# Train Loss: 1.5437 Acc.: 31.64 %
# Val Loss: 1.5352 Acc.: 33.88 %
#
# Epoc 3/99
# ----------
# Train Loss: 1.5261 Acc.: 33.51 %
# Val Loss: 1.5196 Acc.: 35.42 %
#
# Epoc 4/99
# ----------
# Train Loss: 1.5086 Acc.: 34.55 %
# Val Loss: 1.5029 Acc.: 35.24 %
#
# Epoc 5/99
# ----------
# Train Loss: 1.4862 Acc.: 36.45 %
# Val Loss: 1.4837 Acc.: 36.15 %
#
# Epoc 6/99
# ----------
# Train Loss: 1.4671 Acc.: 37.28 %
# Val Loss: 1.4651 Acc.: 36.24 %
#
# Epoc 7/99
# ----------
# Train Loss: 1.4437 Acc.: 39.17 %
# Val Loss: 1.4471 Acc.: 36.51 %
#
# Epoc 8/99
# ----------
# Train Loss: 1.4225 Acc.: 39.55 %
# Val Loss: 1.4271 Acc.: 36.60 %
#
# Epoc 9/99
# ----------
# Train Loss: 1.4012 Acc.: 40.33 %
# Val Loss: 1.4096 Acc.: 37.24 %
#
# Epoc 10/99
# ----------
# Train Loss: 1.3831 Acc.: 41.15 %
# Val Loss: 1.3942 Acc.: 37.33 %
#
# Epoc 11/99
# ----------
# Train Loss: 1.3655 Acc.: 41.54 %
# Val Loss: 1.3831 Acc.: 37.78 %
#
# Epoc 12/99
# ----------
# Train Loss: 1.3476 Acc.: 42.92 %
# Val Loss: 1.3699 Acc.: 38.15 %
#
# Epoc 13/99
# ----------
# Train Loss: 1.3358 Acc.: 42.92 %
# Val Loss: 1.3599 Acc.: 38.51 %
#
# Epoc 14/99
# ----------
# Train Loss: 1.3176 Acc.: 44.26 %
# Val Loss: 1.3528 Acc.: 38.60 %
#
# Epoc 15/99
# ----------
# Train Loss: 1.3086 Acc.: 43.77 %
# Val Loss: 1.3442 Acc.: 39.06 %
#
# Epoc 16/99
# ----------
# Train Loss: 1.3017 Acc.: 44.91 %
# Val Loss: 1.3385 Acc.: 39.33 %
#
# Epoc 17/99
# ----------
# Train Loss: 1.2882 Acc.: 45.51 %
# Val Loss: 1.3318 Acc.: 39.87 %
#
# Epoc 18/99
# ----------
# Train Loss: 1.2786 Acc.: 45.65 %
# Val Loss: 1.3280 Acc.: 39.96 %
#
# Epoc 19/99
# ----------
# Train Loss: 1.2707 Acc.: 45.80 %
# Val Loss: 1.3235 Acc.: 40.05 %
#
# Epoc 20/99
# ----------
# Train Loss: 1.2646 Acc.: 45.99 %
# Val Loss: 1.3204 Acc.: 40.15 %
#
# Epoc 21/99
# ----------
# Train Loss: 1.2527 Acc.: 47.12 %
# Val Loss: 1.3165 Acc.: 40.15 %
#
# Epoc 22/99
# ----------
# Train Loss: 1.2476 Acc.: 47.51 %
# Val Loss: 1.3149 Acc.: 40.42 %
#
# Epoc 23/99
# ----------
# Train Loss: 1.2376 Acc.: 47.86 %
# Val Loss: 1.3122 Acc.: 40.69 %
#
# Epoc 24/99
# ----------
# Train Loss: 1.2287 Acc.: 48.44 %
# Val Loss: 1.3078 Acc.: 41.05 %
#
# Epoc 25/99
# ----------
# Train Loss: 1.2113 Acc.: 49.20 %
# Val Loss: 1.3046 Acc.: 41.42 %
#
# Epoc 26/99
# ----------
# Train Loss: 1.2120 Acc.: 49.29 %
# Val Loss: 1.3051 Acc.: 40.78 %
#
# Epoc 27/99
# ----------
# Train Loss: 1.2053 Acc.: 50.11 %
# Val Loss: 1.3000 Acc.: 41.96 %
#
# Epoc 28/99
# ----------
# Train Loss: 1.1970 Acc.: 50.43 %
# Val Loss: 1.2997 Acc.: 41.60 %
#
# Epoc 29/99
# ----------
# Train Loss: 1.1902 Acc.: 51.09 %
# Val Loss: 1.2975 Acc.: 41.69 %
#
# Epoc 30/99
# ----------
# Train Loss: 1.1848 Acc.: 51.03 %
# Val Loss: 1.2981 Acc.: 41.33 %
#
# Epoc 31/99
# ----------
# Train Loss: 1.1780 Acc.: 51.66 %
# Val Loss: 1.2932 Acc.: 41.60 %
#
# Epoc 32/99
# ----------
# Train Loss: 1.1713 Acc.: 51.53 %
# Val Loss: 1.2940 Acc.: 41.96 %
#
# Epoc 33/99
# ----------
# Train Loss: 1.1672 Acc.: 51.62 %
# Val Loss: 1.2926 Acc.: 42.14 %
#
# Epoc 34/99
# ----------
# Train Loss: 1.1567 Acc.: 53.32 %
# Val Loss: 1.2900 Acc.: 42.33 %
#
# Epoc 35/99
# ----------
# Train Loss: 1.1453 Acc.: 53.24 %
# Val Loss: 1.2908 Acc.: 42.14 %
#
# Epoc 36/99
# ----------
# Train Loss: 1.1401 Acc.: 53.85 %
# Val Loss: 1.2885 Acc.: 42.33 %
#
# Epoc 37/99
# ----------
# Train Loss: 1.1326 Acc.: 54.73 %
# Val Loss: 1.2897 Acc.: 42.23 %
#
# Epoc 38/99
# ----------
# Train Loss: 1.1235 Acc.: 54.54 %
# Val Loss: 1.2857 Acc.: 42.60 %
#
# Epoc 39/99
# ----------
# Train Loss: 1.1214 Acc.: 55.07 %
# Val Loss: 1.2884 Acc.: 42.33 %
#
# Epoc 40/99
# ----------
# Train Loss: 1.1113 Acc.: 55.50 %
# Val Loss: 1.2861 Acc.: 42.33 %
#
# Epoc 41/99
# ----------
# Train Loss: 1.1038 Acc.: 56.25 %
# Val Loss: 1.2853 Acc.: 42.33 %
#
# Epoc 42/99
# ----------
# Train Loss: 1.0944 Acc.: 56.11 %
# Val Loss: 1.2868 Acc.: 42.33 %
#
# Epoc 43/99
# ----------
# Train Loss: 1.0943 Acc.: 56.82 %
# Val Loss: 1.2833 Acc.: 42.60 %
#
# Epoc 44/99
# ----------
# Train Loss: 1.0815 Acc.: 57.24 %
# Val Loss: 1.2823 Acc.: 42.60 %
#
# Epoc 45/99
# ----------
# Train Loss: 1.0786 Acc.: 57.74 %
# Val Loss: 1.2860 Acc.: 42.14 %
#
# Epoc 46/99
# ----------
# Train Loss: 1.0718 Acc.: 58.49 %
# Val Loss: 1.2806 Acc.: 43.05 %
#
# Epoc 47/99
# ----------
# Train Loss: 1.0691 Acc.: 58.08 %
# Val Loss: 1.2819 Acc.: 42.60 %
#
# Epoc 48/99
# ----------
# Train Loss: 1.0542 Acc.: 58.84 %
# Val Loss: 1.2809 Acc.: 43.14 %
#
# Epoc 49/99
# ----------
# Train Loss: 1.0500 Acc.: 58.92 %
# Val Loss: 1.2790 Acc.: 43.05 %
#
# Epoc 50/99
# ----------
# Train Loss: 1.0438 Acc.: 59.06 %
# Val Loss: 1.2810 Acc.: 42.78 %
#
# Epoc 51/99
# ----------
# Train Loss: 1.0354 Acc.: 60.52 %
# Val Loss: 1.2793 Acc.: 42.87 %
#
# Epoc 52/99
# ----------
# Train Loss: 1.0291 Acc.: 60.59 %
# Val Loss: 1.2804 Acc.: 42.78 %
#
# Epoc 53/99
# ----------
# Train Loss: 1.0231 Acc.: 61.00 %
# Val Loss: 1.2800 Acc.: 42.69 %
#
# Epoc 54/99
# ----------
# Train Loss: 1.0160 Acc.: 61.32 %
# Val Loss: 1.2791 Acc.: 42.78 %
#
# Epoc 55/99
# ----------
# Train Loss: 1.0098 Acc.: 61.21 %
# Val Loss: 1.2816 Acc.: 42.78 %
#
# Epoc 56/99
# ----------
# Train Loss: 1.0049 Acc.: 61.84 %
# Val Loss: 1.2795 Acc.: 42.96 %
#
# Epoc 57/99
# ----------
# Train Loss: 0.9958 Acc.: 62.78 %
# Val Loss: 1.2804 Acc.: 42.23 %
#
# Epoc 58/99
# ----------
# Train Loss: 0.9869 Acc.: 62.41 %
# Val Loss: 1.2794 Acc.: 42.78 %
#
# Epoc 59/99
# ----------
# Train Loss: 0.9848 Acc.: 62.93 %
# Val Loss: 1.2803 Acc.: 42.69 %
#
# Epoc 60/99
# ----------
# Train Loss: 0.9797 Acc.: 62.86 %
# Val Loss: 1.2786 Acc.: 42.96 %
#
# Epoc 61/99
# ----------
# Train Loss: 0.9654 Acc.: 64.43 %
# Val Loss: 1.2803 Acc.: 43.05 %
#
# Epoc 62/99
# ----------
# Train Loss: 0.9672 Acc.: 64.01 %
# Val Loss: 1.2843 Acc.: 42.78 %
#
# Epoc 63/99
# ----------
# Train Loss: 0.9584 Acc.: 63.81 %
# Val Loss: 1.2805 Acc.: 43.32 %
#
# Epoc 64/99
# ----------
# Train Loss: 0.9517 Acc.: 65.00 %
# Val Loss: 1.2798 Acc.: 43.05 %
#
# Epoc 65/99
# ----------
# Train Loss: 0.9468 Acc.: 65.26 %
# Val Loss: 1.2818 Acc.: 42.60 %
#
# Epoc 66/99
# ----------
# Train Loss: 0.9352 Acc.: 65.44 %
# Val Loss: 1.2809 Acc.: 43.32 %
#
# Epoc 67/99
# ----------
# Train Loss: 0.9320 Acc.: 65.44 %
# Val Loss: 1.2839 Acc.: 43.05 %
#
# Epoc 68/99
# ----------
# Train Loss: 0.9190 Acc.: 66.87 %
# Val Loss: 1.2854 Acc.: 42.33 %
#
# Epoc 69/99
# ----------
# Train Loss: 0.9171 Acc.: 66.91 %
# Val Loss: 1.2843 Acc.: 43.23 %
#
# Epoc 70/99
# ----------
# Train Loss: 0.9158 Acc.: 66.91 %
# Val Loss: 1.2856 Acc.: 43.23 %
#
# Epoc 71/99
# ----------
# Train Loss: 0.9063 Acc.: 67.44 %
# Val Loss: 1.2842 Acc.: 42.87 %
#
# Epoc 72/99
# ----------
# Train Loss: 0.8987 Acc.: 68.11 %
# Val Loss: 1.2870 Acc.: 43.14 %
#
# Epoc 73/99
# ----------
# Train Loss: 0.8931 Acc.: 67.47 %
# Val Loss: 1.2891 Acc.: 42.51 %
#
# Epoc 74/99
# ----------
# Train Loss: 0.8821 Acc.: 68.34 %
# Val Loss: 1.2861 Acc.: 42.96 %
#
# Epoc 75/99
# ----------
# Train Loss: 0.8762 Acc.: 69.82 %
# Val Loss: 1.2903 Acc.: 42.96 %
#
# Epoc 76/99
# ----------
# Train Loss: 0.8730 Acc.: 69.25 %
# Val Loss: 1.2883 Acc.: 43.32 %
#
# Epoc 77/99
# ----------
# Train Loss: 0.8660 Acc.: 69.21 %
# Val Loss: 1.2887 Acc.: 42.96 %
#
# Epoc 78/99
# ----------
# Train Loss: 0.8611 Acc.: 69.49 %
# Val Loss: 1.2895 Acc.: 43.14 %
#
# Epoc 79/99
# ----------
# Train Loss: 0.8555 Acc.: 69.96 %
# Val Loss: 1.2881 Acc.: 42.78 %
#
# Epoc 80/99
# ----------
# Train Loss: 0.8464 Acc.: 70.63 %
# Val Loss: 1.2895 Acc.: 43.05 %
#
# Epoc 81/99
# ----------
# Train Loss: 0.8412 Acc.: 70.79 %
# Val Loss: 1.2926 Acc.: 42.14 %
#
# Epoc 82/99
# ----------
# Train Loss: 0.8341 Acc.: 70.94 %
# Val Loss: 1.2977 Acc.: 43.05 %
#
# Epoc 83/99
# ----------
# Train Loss: 0.8308 Acc.: 70.86 %
# Val Loss: 1.2949 Acc.: 42.69 %
#
# Epoc 84/99
# ----------
# Train Loss: 0.8220 Acc.: 71.30 %
# Val Loss: 1.2952 Acc.: 42.87 %
#
# Epoc 85/99
# ----------
# Train Loss: 0.8134 Acc.: 72.38 %
# Val Loss: 1.2921 Acc.: 42.60 %
#
# Epoc 86/99
# ----------
# Train Loss: 0.8094 Acc.: 72.38 %
# Val Loss: 1.2937 Acc.: 43.05 %
#
# Epoc 87/99
# ----------
# Train Loss: 0.8050 Acc.: 72.54 %
# Val Loss: 1.2978 Acc.: 42.69 %
#
# Epoc 88/99
# ----------
# Train Loss: 0.8026 Acc.: 72.69 %
# Val Loss: 1.2986 Acc.: 42.33 %
#
# Epoc 89/99
# ----------
# Train Loss: 0.7925 Acc.: 73.77 %
# Val Loss: 1.2973 Acc.: 41.87 %
#
# Epoc 90/99
# ----------
# Train Loss: 0.7840 Acc.: 73.86 %
# Val Loss: 1.2972 Acc.: 42.33 %
#
# Epoc 91/99
# ----------
# Train Loss: 0.7758 Acc.: 74.12 %
# Val Loss: 1.2997 Acc.: 42.78 %
#
# Epoc 92/99
# ----------
# Train Loss: 0.7765 Acc.: 73.68 %
# Val Loss: 1.2977 Acc.: 42.23 %
#
# Epoc 93/99
# ----------
# Train Loss: 0.7662 Acc.: 74.12 %
# Val Loss: 1.3036 Acc.: 42.05 %
#
# Epoc 94/99
# ----------
# Train Loss: 0.7597 Acc.: 74.34 %
# Val Loss: 1.3057 Acc.: 42.51 %
#
# Epoc 95/99
# ----------
# Train Loss: 0.7578 Acc.: 74.89 %
# Val Loss: 1.3044 Acc.: 42.33 %
#
# Epoc 96/99
# ----------
# Train Loss: 0.7526 Acc.: 75.09 %
# Val Loss: 1.3048 Acc.: 42.33 %
#
# Epoc 97/99
# ----------
# Train Loss: 0.7426 Acc.: 75.35 %
# Val Loss: 1.3055 Acc.: 42.42 %
#
# Epoc 98/99
# ----------
# Train Loss: 0.7371 Acc.: 75.99 %
# Val Loss: 1.3081 Acc.: 41.69 %
#
# Epoc 99/99
# ----------
# Train Loss: 0.7378 Acc.: 75.26 %
# Val Loss: 1.3098 Acc.: 42.69 %
#
# Training complete in 2m 26s
# Best Accuracy: 43.32 %

# %%
def test(model):
    model.eval()
    running_corrects = 0
    with torch.no_grad():
        for index, data in enumerate(dataloaders['test']):
            inputs, labels = data.text[0], data.label
            labels.sub_(1)
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            running_corrects += torch.sum(preds == labels).item()
    test_acc = running_corrects / len(dataloaders['test'].dataset)
    print('Test Acc.: {:.2f} %'.format(test_acc * 100))

# %%
test(model)
# Out:
# Test Acc.: 45.29 %
